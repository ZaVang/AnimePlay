# %%
from bangumi_asset.bangumi_api import get_subject_by_id, search_subjects, get_subject_image
from bangumi_asset.models import SearchSubjectsRequest, SearchSubjectsFilter, SubjectType

# %%
req = SearchSubjectsRequest(
    keyword="",
    sort="rank",
    filter=SearchSubjectsFilter(
        type=[2],
        meta_tags=["日本"],
        rank=[">=1", "<=500"]
    )
)
a = search_subjects(req, limit=20, offset=20)

# %%
a.data
# Out:
# [Subject(id=263750, type=<SubjectType.ANIME: 2>, name='進撃の巨人 Season 3 Part.2', name_cn='进击的巨人 第三季 Part.2', summary='历经百年的时光，将人类与外侧世界隔开的墙壁。在墙壁的另一侧，似乎有前所未见的世界延伸开来。火焰之水、冰之大地、砂之雪原……记载在书中的，尽是些激发少年探究心的文字。在时间流转，墙壁被巨人毁坏的现在，人类正一步步接近世界的真相。巨人的真实身份是什麽？为何墙壁中会埋著巨人？巨人化的艾伦·耶格尔所持有的“坐标”之力是？以及，希斯特莉亚·雷斯究竟知道这个世界的什麽事情？在艾伦等104期兵的加入下，建立新体制的利威尔班。最强最恶的敌人，阻拦在开始行动的他们面前。', nsfw=False, locked=False, date='2019-04-28', platform='TV', images=Images(large='https://lain.bgm.tv/pic/cover/l/c2/56/263750_56TBs.jpg', common='https://lain.bgm.tv/r/400/pic/cover/l/c2/56/263750_56TBs.jpg', medium='https://lain.bgm.tv/r/800/pic/cover/l/c2/56/263750_56TBs.jpg', small='https://lain.bgm.tv/r/200/pic/cover/l/c2/56/263750_56TBs.jpg', grid='https://lain.bgm.tv/r/100/pic/cover/l/c2/56/263750_56TBs.jpg'), infobox=[WikiInfo(key='中文名', value='进击的巨人 第三季 Part.2'), WikiInfo(key='别名', value=[WikiInfoValueItem(v='自由之翼 3 Part.2', k=None), WikiInfoValueItem(v='Attack on Titan Season 3 Part.2', k=None), WikiInfoValueItem(v='Shingeki no Kyojin
# ...
